# %%
# Cleaned Submission

import pandas as pd
import numpy as np

# Change later so others can get it on their computer (debaaaaaaaaaaaaajo)

employees = pd.read_csv("C:/Users/Michael Botelho/bip-python-unh/user_audit/data/employees.csv")
system_access = pd.read_csv("C:/Users/Michael Botelho/bip-python-unh/user_audit/data/system_access.csv")


##### Cleaning ID's that works
system_access = system_access.astype(str)
str(system_access['id'])
system_access['id'] = system_access['id'].apply('EMP''{:0>6}'.format)
str(employees['employee_number'])

##### Merge Datasets

df = pd.merge(employees, system_access, left_on='employee_number', right_on='id',  how='outer')


##### Filter for missing values

df.isnull().any()

##### Subset of records that are missing
 
nd = df[df.isnull().any(axis=1)]


##### Set Access Level according to Title


conditions = [
    (df['title'] == 'Sales Assistant'),
    (df['title'] == 'Account Manager'),
(df['title'] == 'Director of Sales')]

values = ['Contract Entry', 'Account Admin', 'Approval - Manager']
df['access_level'] = np.select(conditions, values)
del df['id']

#pd.set_option('display.max_rows', None)

df
# Out:
#     employee_number    first_name       last_name  \
# 0         EMP003037       Juliana        Burbudge
# 1         EMP003045        Lizzie            Blue
# 2         EMP003051       Marjory        Selcraig
# 3         EMP003068        Aguste        O'Connor
# 4         EMP003097       Clemens          Kopman
# 5         EMP003133      Donielle         Midgley
# 6         EMP003134       Marcela          Thieme
# 7         EMP003180         Haily         Wadeson
# 8         EMP003265        Natala            Judd
# 9         EMP003287         Gayla           Aldin
# 10        EMP003291       Gweneth          Abbate
# 11        EMP003299         Nerte         Luipold
# 12        EMP003308          Vere         Gateman
# 13        EMP003344       Cristie        Greenier
# 14        EMP003390        Reuben         Huetson
# 15        EMP003404        Randie        Dimbylow
# 16        EMP003433         Becka       Crutchley
# 17        EMP003434        Elwira          Hedden
# 18        EMP003437        Harrie           Daber
# 19        EMP003452         Cordy        Di Boldi
# 20        EMP003482           Gil            Wife
# 21        EMP003532        Debbie         Linnett
# 22        EMP003588      Beverlie          Meindl
# 23        EMP003605          Jany          Bianco
# 24        EMP003664        Nicola         Odgaard
# 25        EMP003668          Mara         Hassard
# 26        EMP003684      Annmarie         Scrange
# 27        EMP003691      Aldridge    des Remedios
# 28        EMP003713      Marybeth         Driussi
# 29        EMP003734         Lewes         Beadles
# 30        EMP003737       Brandyn          Linnit
# 31        EMP003765       Auberta           Arens
# 32        EMP003773          Ches         Chidlow
# 33        EMP003783         Laure        Blakeway
# 34        EMP003789        Sheila        McMeekin
# 35        EMP003874     Robinetta           Levet
# 36        EMP003886      La verne            Jorn
# 37        EMP003889        Richie           Gorry
# 38        EMP003921      Sigfried          McTear
# 39        EMP003925       Merilee       Dominguez
# 40        EMP003941    Franciskus        Langland
# 41        EMP003950        Briano            Buey
# 42        EMP003952       Shandee          Apfler
# 43        EMP003957      Gerianne       Behnecken
# 44        EMP003969     Valentine         Giddens
# 45        EMP004001         Lanna        Bredbury
# 46        EMP004037       Arnaldo           Snugg
# 47        EMP004042       Amerigo         Carette
# 48        EMP004072      Ethelind         Bostick
# 49        EMP004074       Joachim        Kilmurry
# 50        EMP004076         Bengt        Pogosian
# 51        EMP004085      Shurlock       Mitcheson
# 52        EMP004098          Guss          Soames
# 53        EMP004113       Tiphani          Witter
# 54        EMP004185          Cory          Carter
# 55        EMP004254        Seward          Massen
# 56        EMP004264        Ardisj        Erickson
# 57        EMP004278         Mozes         Veldman
# 58        EMP004348        Kelsey         Buntine
# 59        EMP004349           Zak          Rigney
# 60        EMP004350        Ariela        Smorthit
# 61        EMP004407       Caresse         Stookes
# 62        EMP004426          Tory         Houlson
# 63        EMP004428        Andris          Reekie
# 64        EMP004456     Theresita         Grinval
# 65        EMP004461      Josselyn        Ivanchov
# 66        EMP004476         Danya            Mote
# 67        EMP004511        Amandy        De Lacey
# 68        EMP004514     Sylvester      Santacrole
# 69        EMP004523      Ursuline         Shirley
# 70        EMP004541           Cyb       Bellhouse
# 71        EMP004594         Janet          Eckart
# 72        EMP004608          Loni           Cough
# 73        EMP004613        Lorrie        Trulocke
# 74        EMP004618        Rhodia         Hellier
# 75        EMP004633           Vin         Smissen
# 76        EMP004635      Clarette         Tassell
# 77        EMP004642     Bartolemo         Manwell
# 78        EMP004686      Isabelle        McMillan
# 79        EMP004700         Leese       Greendale
# 80        EMP004708       Carling         Janecek
# 81        EMP004729        Flossy          Scotts
# 82        EMP004752       Jewelle        Fibbitts
# 83        EMP004764      Charlean          Klimke
# 84        EMP004838         Matty          Vankov
# 85        EMP004870      Nicolina       Glasscock
# 86        EMP004876         Kacie         Daglish
# 87        EMP004891          Ynez         Ledster
# 88        EMP004932         Neils        Crosland
# 89        EMP004948           Ted          McNabb
# 90        EMP004964         Karyl     Hamberstone
# 91        EMP004973        Rupert          Mynett
# 92        EMP005006      Kariotta          Curman
# 93        EMP005023     Corabella          Sibbit
# 94        EMP005044         Tonia        Doerffer
# 95        EMP005111         Mavra         Vamplus
# 96        EMP005132          Omar        Colegate
# 97        EMP005134          Jami         Cornall
# 98        EMP005148        Lucila       Bolderson
# 99        EMP005189         Jecho       Francklin
# 100       EMP005242       Sheilah        Castagne
# 101       EMP005259      Chadwick          Seeler
# 102       EMP005265        Arturo      McIlwraith
# 103       EMP005282         Lexis         Roberto
# 104       EMP005289     Cassandra        Ritmeier
# 105       EMP005295       Coretta      Andryushin
# 106       EMP005323       Brockie      Swateridge
# 107       EMP005324         Murry          Zarfat
# 108       EMP005335      Charmion         Garnall
# 109       EMP005341         Terra          Jowitt
# 110       EMP005346       Lazarus          Ortelt
# 111       EMP005368       Vidovik          Caston
# 112       EMP005398          Cale         Marquet
# 113       EMP005429      Clarance        Sneesbie
# 114       EMP005434      Vittorio       Barkshire
# 115       EMP005484      Rebbecca        Trelevan
# 116       EMP005507      Nickolas         Fronzek
# 117       EMP005548        Cyndie       Corbridge
# 118       EMP005556         Irina          Lerven
# 119       EMP005561         Perry             Ash
# 120       EMP005614       Leonora           Stert
# 121       EMP005668      Simmonds       O'Crigane
# 122       EMP005770       Marylin          Chaulk
# 123       EMP005803         Kiley         Willman
# 124       EMP005804         Selig          Iliffe
# 125       EMP005816        Mollee           Bahde
# 126       EMP005835        Kellby          Ludlom
# 127       EMP005839        Chanda           Capey
# 128       EMP005855     Marsiella           Diben
# 129       EMP005872         Jasun        Carnihan
# 130       EMP005889         Fanni            Aird
# 131       EMP005915          Cale         Stigger
# 132       EMP005920      Kimberly           Artus
# 133       EMP005929      Beatrice           Abdee
# 134       EMP005934          Zora        Cardenas
# 135       EMP005941         Drusy          Tramel
# 136       EMP005975          Shem        Denziloe
# 137       EMP005992       Delcine          Spurge
# 138       EMP005993        Isacco           Artis
# 139       EMP006018          Ryan       Daughtrey
# 140       EMP006048     Marylynne          Mannin
# 141       EMP006091         Caryn        Spackman
# 142       EMP006217       Annabal        MacCague
# 143       EMP006227        Elwood        Brindley
# 144       EMP006238         Hubey         Ganford
# 145       EMP006274         Johny         McHardy
# 146       EMP006279          Cory       Stennings
# 147       EMP006309     Armstrong          Munroe
# 148       EMP006372       Halette        MacRirie
# 149       EMP006453     Josephina           Easby
# 150       EMP006471    Melisandra          Kyston
# 151       EMP006493      Trumaine         Swatman
# 152       EMP006513       Sigmund           Georg
# 153       EMP006529         Denna         Gotobed
# 154       EMP006643         Yetta           Fouch
# 155       EMP006689        Carole           Dyers
# 156       EMP006694          Sven          Caesar
# 157       EMP006700     Enriqueta         Quilkin
# 158       EMP006715         Johna        Boniface
# 159       EMP006775     Sheffield          Bowhey
# 160       EMP006806      Gherardo            Pyke
# 161       EMP006812        Leshia          Sheran
# 162       EMP006820         Janey          Devany
# 163       EMP006825        Boycey       MacGaughy
# 164       EMP006826         Paxon         Battell
# 165       EMP006842         Karly        Coppock.
# 166       EMP006855        Isobel           Revie
# 167       EMP006873           Pat         Allaway
# 168       EMP006874         Dione           Kowal
# 169       EMP006887  Barbara-anne         Grishin
# 170       EMP006956         Anson         Yakubov
# 171       EMP006963          Ward         Stokell
# 172       EMP006982      Danielle           Jenny
# 173       EMP006998        Reidar          Plenty
# 174       EMP007023      Valentia          Dobson
# 175       EMP007048     Guenevere          Lasham
# 176       EMP007088         Donny        Gonzalez
# 177       EMP007112          Olly         Cheater
# 178       EMP007126           Ken          Morais
# 179       EMP007163       Laraine            Noye
# 180       EMP007223         Roana         Stother
# 181       EMP007224          Mord          Kelley
# 182       EMP007284         Lanae            Munn
# 183       EMP007316         Leela          Cheeld
# 184       EMP007319        Phylis        Brundell
# 185       EMP007342         Aldon          Patron
# 186       EMP007345      Broderic          Drohun
# 187       EMP007360         Bengt       Baxandall
# 188       EMP007404          Alex          Elders
# 189       EMP007430      Nannette          Mulvey
# 190       EMP007470       Brander       Trevaskus
# 191       EMP007471         Darcy           Bevar
# 192       EMP007489        Inglis        Burbudge
# 193       EMP007497       Hasheem          Gayton
# 194       EMP007524         Danni         Hebborn
# 195       EMP007529      Benjamen         O'Hearn
# 196       EMP007550        Kennan         Theriot
# 197       EMP007568     Henrietta          Gilbey
# 198       EMP007577          Eada          Lisett
# 199       EMP007582         Grace      Macilhench
# 200       EMP007600       Burgess        Mirrlees
# 201       EMP007640          Shep        Moriarty
# 202       EMP007655      Karlotte         Pinshon
# 203       EMP007677       Raphael         Ritzman
# 204       EMP007717         Rheta         Birbeck
# 205       EMP007720         Marve          Dykins
# 206       EMP007726      Fernande         Plastow
# 207       EMP007757        Elissa       Kleinfeld
# 208       EMP007773         Barry          Corder
# 209       EMP007804      Philippe        Comiskey
# 210       EMP007872      Osbourne         Jacmard
# 211       EMP007886        Korney         Riteley
# 212       EMP007937        Millie         Cottham
# 213       EMP007966       Maurits          Vallis
# 214       EMP007984        Cherri         Kohneke
# 215       EMP008036        Philly      Ciabatteri
# 216       EMP008059       Jennine          Saiens
# 217       EMP008074           Ned       Benninger
# 218       EMP008094       Kerstin         Himpson
# 219       EMP008117        Joleen        Kirstein
# 220       EMP008146        Godwin        Pavolini
# 221       EMP008171       Cecelia      Blackaller
# 222       EMP008192        Jillie       Decayette
# 223       EMP008202          Vida           Gaine
# 224       EMP008228        Stacee          Jervis
# 225       EMP008236        Corrie             Job
# 226       EMP008258         Meggy           Amery
# 227       EMP008267     Sallyanne         Keiling
# 228       EMP008270         Laura           Egell
# 229       EMP008314        Krista          Skarin
# 230       EMP008338      Nickolai      Longbothom
# 231       EMP008347      Mignonne          Cowitz
# 232       EMP008420       Madison         Yurygyn
# 233       EMP008421        Lorene          Dutson
# 234       EMP008451       Roxanna          Dungay
# 235       EMP008458          Tami         Deporte
# 236       EMP008472         Cleon          Colley
# 237       EMP008479           Ade        Menelaws
# 238       EMP008499      Tiphanie       Iacovuzzi
# 239       EMP008520          Tana        Conochie
# 240       EMP008539       Jacquie     Fridlington
# 241       EMP008562       Chilton       Antonovic
# 242       EMP008588       Leonerd           Augar
# 243       EMP008607        Angeli         Chalice
# 244       EMP008613        Delora          Morton
# 245       EMP008640        Abramo         Kightly
# 246       EMP008657          Cami         Tanslie
# 247       EMP008677      Frederic          Hockey
# 248       EMP008774       Suzanne          Strick
# 249       EMP008808        Reuben       McAlarney
# 250       EMP008825           Ari        Headland
# 251       EMP008890     Christyna          Farres
# 252       EMP008893        Jorrie       Scottrell
# 253       EMP008897          Fabe          Venart
# 254       EMP008913        Erhart         Ashborn
# 255       EMP008945         Byrle          Lipson
# 256       EMP008977        Carson           Akast
# 257       EMP009016         Nanny        Halfhead
# 258       EMP009080       Amaleta           Poser
# 259       EMP009091     Quintilla         Wegenen
# 260       EMP009099         Quill           Foale
# 261       EMP009143       Timoteo          Lavery
# 262       EMP009153         Horst         Headley
# 263       EMP009160       Stormie           Lortz
# 264       EMP009214         Rahal       Monkhouse
# 265       EMP009217        Arthur          Abbyss
# 266       EMP009234        Terese         Kunzler
# 267       EMP009237        Jessie         McPolin
# 268       EMP009241          Bryn        Goodayle
# 269       EMP009261       Carlota         Aingell
# 270       EMP009279       Burnard        Colliber
# 271       EMP009312         Yance         Wintour
# 272       EMP009354         Selig         Whittek
# 273       EMP009396      Morganne        Kesteven
# 274       EMP009398        Melody       Braitling
# 275       EMP009400       Robinet      Filippazzo
# 276       EMP009416        Fidela         Valerio
# 277       EMP009433       Joelynn        Spelling
# 278       EMP009485       Sanford  De'Vere - Hunt
# 279       EMP009493     Giulietta          Nevins
# 280       EMP009502        Arturo          Lagden
# 281       EMP009504       Giraldo          Loynes
# 282       EMP009505      Immanuel        Rochford
# 283       EMP009509      Marthena           Hynam
# 284       EMP009556       Carolee         Assiter
# 285       EMP009585          Theo        Craghead
# 286       EMP009600         Nonna         Laurens
# 287       EMP009649     Archibald           Reihm
# 288       EMP009699         Laird        Roelvink
# 289       EMP009722       Wernher           Olsen
# 290       EMP009758          Chet        Casellas
# 291       EMP009773          Kenn           Boddy
# 292       EMP009789        Hermia         Boutton
# 293       EMP009802    Georgeanna        MacGiany
# 294       EMP009841        Sidney        Edgcumbe
# 295       EMP009866        Shelby      Christoffe
# 296       EMP009879     Valentino       Mattiacci
# 297       EMP009889      Salvidor           Faich
# 298       EMP009903         Amber         Ainscow
# 299       EMP009905          Lara          Apfler
# 300       EMP009913         Brady       Enderwick
# 301       EMP009917           Yul          Muscat
# 302       EMP009925        Gianni         Dootson
# 303       EMP009998        Meriel          Purves
# 304       EMP010054         Udall          Brixey
# 305       EMP010061        Tulley         Britney
# 306       EMP010155      Lucretia          Figgen
# 307       EMP010172         Fiann       MacCorley
# 308       EMP010184         Meryl         Grammer
# 309       EMP010186        Lynett        Magauran
# 310       EMP010197     Valentine        Wheowall
# 311       EMP010206        Ephrem        Buckland
# 312       EMP010215        Carver         Grennan
# 313       EMP010230           Web           Heims
# 314       EMP010236           Abe          Totman
# 315       EMP010241      Maybelle         Phlippi
# 316       EMP010271      Waldemar         Tamplin
# 317       EMP010275         Silva         Spowart
# 318       EMP010276       Bartlet      Waterstone
# 319       EMP010293      Zacherie        Mityakov
# 320       EMP010312        Warden          Starie
# 321       EMP010323        Burlie        Whitelaw
# 322       EMP010346       Quillan         Leggate
# 323       EMP010358   Ulrikaumeko           Oehme
# 324       EMP010360       Gwenora           Huske
# 325       EMP010366        Arlyne            Lott
# 326       EMP010369         Meggy          Hayhow
# 327       EMP010385        Odessa          Smewin
# 328       EMP010427         Celie          Cannan
# 329       EMP010454       Ellette          Ricard
# 330       EMP010460        Kaycee        Jannaway
# 331       EMP010474      Aridatha        Heningam
# 332       EMP010476       Juanita      Barrington
# 333       EMP010492          Keri           Atley
# 334       EMP010538        Merwyn       Grisedale
# 335       EMP010542        Korney       Oleshunin
# 336       EMP010556      Gilberte         Lantiff
# 337       EMP010633        Paloma         Gopsell
# 338       EMP010637      Willetta         Tricker
# 339       EMP010662         Moria        Bourdice
# 340       EMP010665         Jesse          Gatman
# 341       EMP010693        Dahlia           Agius
# 342       EMP010717      Theobald       Mussolini
# 343       EMP010789          Kara          Cowely
# 344       EMP010792        Reggis          Beddoe
# 345       EMP010809        Galina          Mauger
# 346       EMP010851        Jaclin         Gerrelt
# 347       EMP010864         Hodge        Riccardo
# 348       EMP010883        Aretha          Tailby
# 349       EMP010891      Charlton          Dawtre
# 350       EMP010896         Price      Kettlesing
# 351       EMP010915        Mellie          Hackey
# 352       EMP010938          Bria           Stopp
# 353       EMP010987        Marena         Iannini
# 354       EMP010989        Porter         Harrald
# 355       EMP010997       Leanora           Ricks
# 356       EMP011002     Harriette     Madoc-Jones
# 357       EMP011075        Garrek          Sewley
# 358       EMP011079       Shirlee         Giacobo
# 359       EMP011092         Olvan       Andriolli
# 360       EMP011099      Fielding          Fitkin
# 361       EMP011112         Phebe         Bulleyn
# 362       EMP011121        Feliks          Steers
# 363       EMP011122        Nestor         Pancost
# 364       EMP011154   Clerkclaude          Atthow
# 365       EMP011160     Corrianne        Pothbury
# 366       EMP011167       Carolyn       Fouracres
# 367       EMP011176      Valdemar       Athelstan
# 368       EMP011186        Mischa          Fowley
# 369       EMP011211       Beverie           Monks
# 370       EMP011250       Bryanty       Corselles
# 371       EMP011264       Amalita         Rustman
# 372       EMP011285          Ches         Wiffler
# 373       EMP011293           Deb       De Freyne
# 374       EMP011305     Hyacintha         Adamiec
# 375       EMP011323        Tildie     Collingwood
# 376       EMP011336        Daphna           Eliff
# 377       EMP011342       Aurelie          Montes
# 378       EMP011372     Claiborne           Rowet
# 379       EMP011446        Arleen          Sissel
# 380       EMP011450           Roy         Skeeles
# 381       EMP011464     Maryellen           Carle
# 382       EMP011480       Celinda         Hamblen
# 383       EMP011546       Christy       Aberdalgy
# 384       EMP011599        Brnaba          Marson
# 385       EMP011625        Antony          Owlner
# 386       EMP011657      Torrence          Umfrey
# 387       EMP011672         Tades     Abramowitch
# 388       EMP011702       Emiline        Grimston
# 389       EMP011708        Emylee          Tibald
# 390       EMP011774          Iago         Farnham
# 391       EMP011778        Marget        Thowless
# 392       EMP011790       Margret          Hursey
# 393       EMP011858        Currey          Waldie
# 394       EMP011866        Eloise          Hirche
# 395       EMP011869       Robinet           Diano
# 396       EMP011877        Yelena            Saer
# 397       EMP011883        Sabina        Killough
# 398       EMP011897        Cloris        Bernardt
# 399       EMP011950        Kirbie       Legerwood
# 400       EMP011975      Marcella       Handyside
# 401       EMP012003          Alec           Hatry
# 402       EMP012065        Karlis       Bartoloma
# 403       EMP012103         Latia         Sawtell
# 404       EMP012104        Agneta       Tremollet
# 405       EMP012126    Wilhelmine          Cerman
# 406       EMP012142    Cirstoforo         Leppard
# 407       EMP012156         Syman       Randerson
# 408       EMP012172        Tomlin        Bowering
# 409       EMP012176      Eugenius       Teodorski
# 410       EMP012181        Gustie          McKain
# 411       EMP012189        Ronald         Rampage
# 412       EMP012198         Honor            Eary
# 413       EMP012211       Vitoria            Dews
# 414       EMP012272        Carlos        Hardiman
# 415       EMP012278         Jeddy       McClymond
# 416       EMP012296           Gil          Riolfi
# 417       EMP012306       Rudiger         Leneham
# 418       EMP012327        Aeriel         McOmish
# 419       EMP012347          Kale         Dubique
# 420       EMP012360      Christie         Driuzzi
# 421       EMP012409         Gabby         Smelley
# 422       EMP012422         Inigo          Morsom
# 423       EMP012435        Adolph       Scrivenor
# 424       EMP012456        Gretta        Pauletti
# 425       EMP012465           Lon          Kenton
# 426       EMP012479         Penny        Tiddeman
# 427       EMP012529         Adela       Pettiford
# 428       EMP012542          Sean          Yeiles
# 429       EMP012560       Doralia        Thomkins
# 430       EMP012606       Ameline         Davioud
# 431       EMP012626        Edmund         Kernley
# 432       EMP012646         Clare       Follacaro
# 433       EMP012667        Hermia         Leibold
# 434       EMP012683          Itch      Gouldstone
# 435       EMP012771        Jobyna          Pixton
# 436       EMP012783        Elston           Cloke
# 437       EMP012822         Jamal      Cammiemile
# 438       EMP012836         Drusi        Braizier
# 439       EMP012926      Mitchael         Lalevee
# 440       EMP012961         Alika          Croser
# 441       EMP012972       Phaidra            Iley
# 442       EMP013022    Christiana          Axelby
# 443       EMP013049        Alaric       Morefield
# 444       EMP013105        Wandis           Myall
# 445       EMP013130       Rodolfo       Scripture
# 446       EMP013156      Ingeberg        Capeloff
# 447       EMP013179       Brockie      McCalister
# 448       EMP013210         Daisy         Quernel
# 449       EMP013216        Cyndie         Authers
# 450       EMP013241      Atalanta          Edward
# 451       EMP013261         Reiko        Burnsyde
# 452       EMP013312          Audi       Addington
# 453       EMP013369       Clayson           Dudny
# 454       EMP013448       Geralda        Heberden
# 455       EMP013466         Colby         Lamblot
# 456       EMP013560     Laurianne          Healey
# 457       EMP013574        Lorens           Nodin
# 458       EMP013578       Sephira      Throughton
# 459       EMP013589        Curran           Smyth
# 460       EMP013598         Darby         Robshaw
# 461       EMP013636           Zak         Pieters
# 462       EMP013646        Nancey         Dineges
# 463       EMP013668       Enrique         Warlock
# 464       EMP013682        Gizela         Bardell
# 465       EMP013688     Kara-lynn          Darcey
# 466       EMP013704       Therine          Emmert
# 467       EMP013748          Reta      Talkington
# 468       EMP013788        Cullie            Kyle
# 469       EMP013856        Tomaso        Schirach
# 470       EMP013864        Athena           Mixon
# 471       EMP013867        Noelyn          Bustin
# 472       EMP013886        Siffre          Janaud
# 473       EMP013889      Hugibert     Birtwhistle
# 474       EMP013984        Willey         Harbach
# 475       EMP014015         Pavla         Newbury
# 476       EMP014058       Robenia           Celle
# 477       EMP014096        Shelly     Cecchetelli
# 478       EMP014132         Wylie         Wardlow
# 479       EMP014148          Saxe          Bungey
# 480       EMP014165          Noah      Franciotti
# 481       EMP014177       Mikaela          Meindl
# 482       EMP014208         Eddie         Nutting
# 483       EMP014219         Randy         Angless
# 484       EMP014234         Byran        Stearley
# 485       EMP014240          Gran       Johnstone
# 486       EMP014262      Northrup           Bowen
# 487       EMP014275      Clotilda          Dauney
# 488       EMP014304        Justen      McGettigan
# 489       EMP014331       Webster       Willicott
# 490       EMP014374       Merilyn          Sabbin
# 491       EMP014392         Auria        Brockley
# 492       EMP014433         Nicol          Casine
# 493       EMP014435      Carmelia     Artingstall
# 494       EMP014442      Brantley         Beadham
# 495       EMP014467         Berne         Klugman
# 496       EMP014474         Barbi         Isaksen
# 497       EMP014520        Randie           Rowan
# 498       EMP014536         Lefty        Edgcumbe
# 499       EMP014552     Westleigh           Natte
# 500       EMP014636         Lukas   Van der Hoven
# 501       EMP014663        Hadlee          Stucke
# 502       EMP014674        Holmes         Classen
# 503       EMP014713           Ora          Kerans
# 504       EMP014737         Storm         Revelle
# 505       EMP014746         Wilma          Fearns
# 506       EMP014760      Patrizia          Novill
# 507       EMP014762       Mozelle          Drohun
# 508       EMP014775   Minnaminnie         Tratton
# 509       EMP014824         Cindi         Hubeaux
# 510       EMP014873       Antonie        Connolly
# 511       EMP014886         Kaleb            Rome
# 512       EMP014892        Jordon          Dibben
# 513       EMP014901         Sasha       Lillegard
# 514       EMP014930        Cookie            Lund
# 515       EMP014936            Bo      Davydzenko
# 516       EMP014954       Chaddie         Writtle
# 517       EMP014956        Krissy          Rumens
# 518       EMP014997        Finlay         Limbert
# 519       EMP015001         Chloe        Chantree
# 520       EMP015017       Coretta       Pengilley
# 521       EMP015053         Jeane           Stuke
# 522       EMP015061       Sergent           Batie
# 523       EMP015131          Glen        Blaskett
# 524       EMP015139        Berthe    Clausen-Thue
# 525       EMP015152       Crystal         Pawlett
# 526       EMP015179         Erinn           Ayris
# 527       EMP015214       Giralda        St Clair
# 528       EMP015242          Trey        Lewendon
# 529       EMP015250         Ilene           Oldis
# 530       EMP015278        Jaimie           Gouny
# 531       EMP015333        Lucius          Scales
# 532       EMP015364          Maia         Stitson
# 533       EMP015380       Valaria         Dulling
# 534       EMP015392        Kellby        Reubbens
# 535       EMP015452         Emyle         Songust
# 536       EMP015483        Lindsy         Mitcham
# 537       EMP015492        Ashlan            Root
# 538       EMP015498      Roshelle        MacAlees
# 539       EMP015556       Austina           Human
# 540       EMP015575        Galven          Flower
# 541       EMP015584          Chad           Coysh
# 542       EMP015603        Pegeen        Lamplugh
# 543       EMP015618         Euell         Tytcomb
# 544       EMP015619        Florry         Bonnick
# 545       EMP015627            Jo          Keeves
# 546       EMP015646        Bourke      Karpushkin
# 547       EMP015651           Way        Sawforde
# 548       EMP015682      Eleanora       Amsberger
# 549       EMP015709        Candra     Swatheridge
# 550       EMP015731     Standford           Coton
# 551       EMP015766       Clarine         Pressey
# 552       EMP015788       Jeremie       Van Halle
# 553       EMP015791          Faun        Hubbocks
# 554       EMP015819        Ulises          Morais
# 555       EMP015830          Jase            Sima
# 556       EMP015862     Rosemarie          Willes
# 557       EMP015863      Marcelia          Raiker
# 558       EMP015915       Emmalyn       Pattesall
# 559       EMP015950       Andreas           Focke
# 560       EMP015957         Allie          Metzel
# 561       EMP015966        Menard          Diviny
# 562       EMP015974        Ferris          Clemon
# 563       EMP016034       Bartram       Shrimpton
# 564       EMP016046        Jemmie        Hellwich
# 565       EMP016062      Adrianne          Felgat
# 566       EMP016079           Ruy        Burhouse
# 567       EMP016084           Tod        Tethacot
# 568       EMP016087         Major         Figgins
# 569       EMP016140          Scot           Slate
# 570       EMP016147         Chris       Klaaassen
# 571       EMP016162          Hunt          Levett
# 572       EMP016177        Filmer         Eborall
# 573       EMP016194          Russ        Brickett
# 574       EMP016240      Maryanna           Ismay
# 575       EMP016246         Drona         Houchen
# 576       EMP016289         Vanny           Scane
# 577       EMP016303        Merell         Tavinor
# 578       EMP016332         Brody          Heeron
# 579       EMP016364          Shaw        Sneesbie
# 580       EMP016365       Gaylene          Cudihy
# 581       EMP016383          Dela        Lishmund
# 582       EMP016428      Flemming            Jerg
# 583       EMP016454        Michel         Baldung
# 584       EMP016487       Erminie          Paylie
# 585       EMP016499         Tyler         Ullrich
# 586       EMP016575        Blanca        Davisson
# 587       EMP016586        Antony        Raselles
# 588       EMP016630        Andrej         Mooring
# 589       EMP016638         Misha             How
# 590       EMP016654      Dionisio        Waszczyk
# 591       EMP016663           Hew          Sayles
# 592       EMP016666          Shay         Bragger
# 593       EMP016669        Vaclav          Alders
# 594       EMP016751           Isa          Attack
# 595       EMP016761       Jo-anne          Barday
# 596       EMP016801       Gwennie         Brouard
# 597       EMP016834          Joey         Esmonde
# 598       EMP016849         Evvie    Kruszelnicki
# 599       EMP016867       Maurene       Challinor
# 600       EMP016892         Hersh      Caudrelier
# 601       EMP016906       Elsbeth           Palek
# 602       EMP016927      Tiffanie          Chipps
# 603       EMP016942        Charla        Assandri
# 604       EMP016963      Jeannine        Hannigan
# 605       EMP017022         Maire        Henighan
# 606       EMP017027      Zacherie             Tal
# 607       EMP017039        Merrie          Bosden
# 608       EMP017065        Barrie           Mines
# 609       EMP017122      Prentiss           Adkin
# 610       EMP017149         Aimee          Bodman
# 611       EMP017162       Maritsa          Wapple
# 612       EMP017209        Brooks          Libero
# 613       EMP017219       Leonora         Kirtlan
# 614       EMP017238          Luce  Erskine Sandys
# 615       EMP017240       Tabitha        Kauschke
# 616       EMP017250     Jacquelin           Claus
# 617       EMP017263        Lazare       Challenor
# 618       EMP017303      Charmain        Redfearn
# 619       EMP017349         Rhett          Adenot
# 620       EMP017354       Ximenes         Gotfrey
# 621       EMP017409         Merry       Blodgetts
# 622       EMP017413        Harris          Everal
# 623       EMP017421         Flint          Eastes
# 624       EMP017475       Antonia         Mounter
# 625       EMP017499     Hortensia       Ingarfill
# 626       EMP017511        Nolana           Spier
# 627       EMP017522        Rossie        Pidgeley
# 628       EMP017532       Stewart         Sapshed
# 629       EMP017547         Janel        Bariball
# 630       EMP017568         Ester           Akitt
# 631       EMP017591      Delphine       Schinetti
# 632       EMP017595        Binnie         Bramble
# 633       EMP017609     Heindrick         Buesnel
# 634       EMP017615        Sophie        Issacoff
# 635       EMP017655      Rebbecca         Pluvier
# 636       EMP017672        Ingram       Pleasance
# 637       EMP017684        Gabbie        Radbourn
# 638       EMP017689          Rici       Batchelor
# 639       EMP017693        Merrel        Maciunas
# 640       EMP017721           Val         McMylor
# 641       EMP017734       Vanessa          Olivia
# 642       EMP017749       Annette          Curran
# 643       EMP017779      Lynnelle         O'Boyle
# 644       EMP017792        Wallis         Huddart
# 645       EMP017804          Lucy        Kinchlea
# 646       EMP017838       Sarette          Beakes
# 647       EMP017881       Ardelia         Willden
# 648       EMP017887      Packston      Janczewski
# 649       EMP017902        Sherry         Aldcorn
# 650       EMP017908         Sofie          Orbine
# 651       EMP017942        Talyah         Tummons
# 652       EMP017944       Lyndsay       Menauteau
# 653       EMP017955        Denney          Stealy
# 654       EMP017956          Rivi       Limpricht
# 655       EMP017999     Christyna         Turland
# 656       EMP018007         Cozmo      Robertacci
# 657       EMP018025        Editha           Maben
# 658       EMP018033      Bradford        Costello
# 659       EMP018094          Hall       Pattesall
# 660       EMP018128         Vally          Emmitt
# 661       EMP018142          Noni           Layus
# 662       EMP018205       Nichols           Noble
# 663       EMP018228       Bennett          Saward
# 664       EMP018294        Rhodie     Barraclough
# 665       EMP018310       Nealson       Shoebrook
# 666       EMP018335        Stavro          Hornig
# 667       EMP018389       Letitia         Coultas
# 668       EMP018406         Kelly      Losselyong
# 669       EMP018424     Gabriello         Belsham
# 670       EMP018431       Vaughan        Swinburn
# 671       EMP018433           Rey           Turle
# 672       EMP018449          Orly        Rowntree
# 673       EMP018533         Jamey         de Nore
# 674       EMP018583        Coleen      Banaszczyk
# 675       EMP018635      Kristian       Brushneen
# 676       EMP018708        Dorice         Blezard
# 677       EMP018762      Murielle           Vegas
# 678       EMP018788        Urbano          Czaple
# 679       EMP018793        Garvin          Durbin
# 680       EMP018854         Denni       Thirlwell
# 681       EMP018855          Zora      Di Claudio
# 682       EMP018866          Mace         Grebbin
# 683       EMP018894       Myrilla           Pioli
# 684       EMP018945     Evangelia        Snowball
# 685       EMP018958      Annmarie            Maud
# 686       EMP019019        Jamesy           Hampe
# 687       EMP019026        Buddie          Jenman
# 688       EMP019087       Helaina          Clemas
# 689       EMP019113         Paton           Etock
# 690       EMP019164      Salomone         Benzing
# 691       EMP019216       Chantal        Llywarch
# 692       EMP019239           Dag         Bygrave
# 693       EMP019247         Zarla          Navaro
# 694       EMP019274         Noble          Povall
# 695       EMP019293       Pauline      Pattingson
# 696       EMP019297     Andriette          Lemmen
# 697       EMP019311         Doyle          Firman
# 698       EMP019341     Llywellyn           Keech
# 699       EMP019420        Yolane          Rustan
# 700       EMP019446           Bev         Tassell
# 701       EMP019458        Valida      MacTrustey
# 702       EMP019462     Cleavland       Shepheard
# 703       EMP019473       Eolanda         Sigfrid
# 704       EMP019493      Morganne      Cattlemull
# 705       EMP019505         Goldy          Sawkin
# 706       EMP019510         Blair        Gytesham
# 707       EMP019516         Paula         Rickett
# 708       EMP019534       Hermina         Mellows
# 709       EMP019573       Camella           Vigne
# 710       EMP019599         Jodie          Kiljan
# 711       EMP019651        Morgen            Marl
# 712       EMP019652         Barny       Quickfall
# 713       EMP019666         Maxie          Tabert
# 714       EMP019676         Ketty          Horley
# 715       EMP019702       Annissa          Moorey
# 716       EMP019703         Maude         Pretley
# 717       EMP019709           Pia           Talby
# 718       EMP019727        Horten         Burdass
# 719       EMP019728      Bernetta          Ballin
# 720       EMP019734       Doralia           Narey
# 721       EMP019760         Sibyl          Gerard
# 722       EMP019807        Karmen           Sutch
# 723       EMP019814      Nikolaus         Getsham
# 724       EMP019816        Peadar        Morstatt
# 725       EMP019830      Clarisse          Ortell
# 726       EMP019867          Crin        Petersen
# 727       EMP019894      Filberto           Poetz
# 728       EMP019904      Richardo      Fitzsymons
# 729       EMP019934         Pansy          Birkby
# 730       EMP019953        Tabbie        Tumbelty
# 731       EMP019975       Juliane           Doyle
# 732       EMP019991         Carri          Marder
# 733       EMP020029       Cornell          Kordas
# 734       EMP020037       Hayward        Antonsen
# 735       EMP020071        Osbert          Gamlyn
# 736       EMP020090      Chandler         Eatttok
# 737       EMP020094       Kimball        Lammertz
# 738       EMP020096         Dyane           Abels
# 739       EMP020100       Harlene            Gori
# 740       EMP020101        Elmira           McGaw
# 741       EMP020103    Jackquelin            Mose
# 742       EMP020105         Reena         Goreway
# 743       EMP020106        Evered        Scollick
# 744       EMP020108       Chrissy         McIntee
# 745       EMP020131         Selma          Storek
# 746       EMP020143       Nerissa          Drogan
# 747       EMP020160       Ichabod        Schultze
# 748       EMP020166      Bethanne           Shugg
# 749       EMP020287         Halsy          Mounch
# 750       EMP020288        Aurlie     MacTerrelly
# 751       EMP020322         Rubin            Dart
# 752       EMP020345         Doyle         Stieger
# 753       EMP020355         Alexi          Gerler
# 754       EMP020358        Anette          Lauder
# 755       EMP020360      Raphaela          Pearch
# 756       EMP020430        Nicoli         Kintish
# 757       EMP020450       Padraic          Ferrey
# 758       EMP020457         Lindi       Tschierse
# 759       EMP020514          Gard          Quayle
# 760       EMP020549        Nathan         Childes
# 761       EMP020566        Sybila          Hoggan
# 762       EMP020601        Dudley         Ransome
# 763       EMP020607          Anny       Franzetti
# 764       EMP020614         Waldo        Kingerby
# 765       EMP020659       Cecilio       Cowlishaw
# 766       EMP020660         Livia          Sleith
# 767       EMP020667       Vassily         Munning
# 768       EMP020672        Stanly       MacArthur
# 769       EMP020679        Sheffy         Hritzko
# 770       EMP020701          Enos       Pimblotte
# 771       EMP020737          Gale         Vannini
# 772       EMP020745          Alex       Treverton
# 773       EMP020758         Mamie        Hastings
# 774       EMP020770         Trude          Braven
# 775       EMP020825        Tulley          Wivell
# 776       EMP020830           Nev     Filipchikov
# 777       EMP020855          Noel     Huddlestone
# 778       EMP020860          Jude       Joskowicz
# 779       EMP020898       Alyosha           Elsey
# 780       EMP020931        Kassia       Apfelmann
# 781       EMP020990        Evelin        Balducci
# 782       EMP021005     Marybelle          Berrie
# 783       EMP021016        Ofelia           Oliff
# 784       EMP021058           Mar           Fairn
# 785       EMP021078          Amby            Jory
# 786       EMP021091        Gillie          Rother
# 787       EMP021128       Madelle        Verecker
# 788       EMP021215         Lilas           Alban
# 789       EMP021261          Garv       Inchboard
# 790       EMP021274        Bourke       Treverton
# 791       EMP021281       Filbert           Bowle
# 792       EMP021284         Pavia        Leathlay
# 793       EMP021291         Corri         Gorring
# 794       EMP021303       Evaleen       Gerritzen
# 795       EMP021313     Catharina         Tippett
# 796       EMP021390         Lamar          Lounds
# 797       EMP021413        Shaina            Lark
# 798       EMP021534      Lauraine      Branscombe
# 799       EMP021541       Beltran           Poole
# 800       EMP021558         Joana      Woolfenden
# 801       EMP021577      Patrizia           Leate
# 802       EMP021592         Myrna        Colleton
# 803       EMP021621          Abbi            Tilt
# 804       EMP021627        Bealle         Stichel
# 805       EMP021644          Zeke       Galbraith
# 806       EMP021657        Brinna       Treadgall
# 807       EMP021713        Ardisj          Giurio
# 808       EMP021746          Chev           Ekell
# 809       EMP021763       Valerie            Leat
# 810       EMP021772         Norby       McKelloch
# 811       EMP021786         Timmi        Reedshaw
# 812       EMP021801        Karole         Anshell
# 813       EMP021814         Tymon           Aldam
# 814       EMP021823        Leland       Jenkinson
# 815       EMP021844       Pauline        Lortzing
# 816       EMP021858           Zak           Heddy
# 817       EMP021874        Aurore          Wavish
# 818       EMP021924        Wildon         Smurfit
# 819       EMP021933        Libbie        Bagguley
# 820       EMP021939         Sabra          Crigin
# 821       EMP021972        Whitby          Frarey
# 822       EMP021986       Opalina          Cloute
# 823       EMP021998       Allissa           Curds
# 824       EMP022014        Israel           Kolin
# 825       EMP022038       Urbanus           Silby
# 826       EMP022050         Aline           March
# 827       EMP022057       Barnard      Jacobowits
# 828       EMP022061          Mort         Kinkade
# 829       EMP022131          Eric         Witnall
# 830       EMP022134         Graig        Wainscot
# 831       EMP022151        Jessee         Keitley
# 832       EMP022171       Theodor        Stuffins
# 833       EMP022251          Joey        Pristnor
# 834       EMP022258        Ramsay         McCowan
# 835       EMP022291          Addy           Wilby
# 836       EMP022331        Wallie          Schott
# 837       EMP022361      Starlene          McCosh
# 838       EMP022364         Sofia           Macci
# 839       EMP022370         Spike        Brithman
# 840       EMP022383          Alia  Von Der Empten
# 841       EMP022407         Elnar       Iacovides
# 842       EMP022424          Tadd           Chant
# 843       EMP022429        Ramsey        Godleman
# 844       EMP022435        Tiffie         Copello
# 845       EMP022486        Breena           Teese
# 846       EMP022488         Iggie        Ottiwill
# 847       EMP022489       Pauline          Dowman
# 848       EMP022492       Starlin       Scrimshaw
# 849       EMP022495        Tracie          Welsby
# 850       EMP022566     Kristofer       McClinton
# 851       EMP022581        Benoit      De Matteis
# 852       EMP022597         Traci           Siret
# 853       EMP022619         Jamil        Gilligan
# 854       EMP022631         Saree        Hardware
# 855       EMP022666        Ruddie          McGlew
# 856       EMP022676      Jerrylee       Kenafaque
# 857       EMP022678          Eula         Sappell
# 858       EMP022695       Artemas         Wardlaw
# 859       EMP022698     Cassandre          Onraet
# 860       EMP022699        Lorrie        Batsford
# 861       EMP022728      Joycelin           Gaule
# 862       EMP022752           Ree         Copozio
# 863       EMP022753          Tome       Heffernon
# 864       EMP022774          Geri          Bizzey
# 865       EMP022802        Kelwin          Bosman
# 866       EMP022867        Hilton     Andrewartha
# 867       EMP022877       Padgett           Lynch
# 868       EMP022878       Walther          Derwin
# 869       EMP022888      Winfield           Scemp
# 870       EMP022893       Diandra        Picknett
# 871       EMP022903          Ring        Stronach
# 872       EMP022936        Amalle         Jackson
# 873       EMP022945         Barry           Chagg
# 874       EMP022989       Hillary          Raspel
# 875       EMP022993         Viole         Cogzell
# 876       EMP022995       Corbett           Seven
# 877       EMP023007     Marmaduke     Threadgould
# 878       EMP023018         Alysa       Colclough
# 879       EMP023033       Jordain            Izat
# 880       EMP023064         Elsie           Cavie
# 881       EMP023069         Sandi         Nuschke
# 882       EMP023109        Deedee         Chippin
# 883       EMP023115      Nicolais         Avramow
# 884       EMP023119        Jessey          Folker
# 885       EMP023149        Torrie        Harefoot
# 886       EMP023152      Lisabeth        Cosgrove
# 887       EMP023164     Bobinette          Sicily
# 888       EMP023169          Lane           Irlam
# 889       EMP023178           Dur            Nand
# 890       EMP023187          Aube        Dallmann
# 891       EMP023253          Cele           Feore
# 892       EMP023267       Nealson          Leaves
# 893       EMP023279        Kattie          Phebey
# 894       EMP023280        Caspar       MacMillan
# 895       EMP023323         Erina           Mowne
# 896       EMP023365        Roanna           Esler
# 897       EMP023383         Lyssa           Wride
# 898       EMP023414         Katti            Bing
# 899       EMP023428        Gibbie    Blackborough
# 900       EMP023439      Reynolds        Hiscocks
# 901       EMP023454       Franzen           Gawke
# 902       EMP023482       Dunstan          Edgars
# 903       EMP023538          Jude         Gaunson
# ...
# 360      Contract Entry
# 361  Approval - Manager
# 362       Account Admin
# 363      Contract Entry
# 364       Account Admin
# 365      Contract Entry
# 366       Account Admin
# 367       Account Admin
# 368       Account Admin
# 369  Approval - Manager
# 370       Account Admin
# 371      Contract Entry
# 372       Account Admin
# 373      Contract Entry
# 374  Approval - Manager
# 375      Contract Entry
# 376       Account Admin
# 377       Account Admin
# 378  Approval - Manager
# 379      Contract Entry
# 380      Contract Entry
# 381      Contract Entry
# 382      Contract Entry
# 383      Contract Entry
# 384      Contract Entry
# 385       Account Admin
# 386       Account Admin
# 387       Account Admin
# 388      Contract Entry
# 389       Account Admin
# 390      Contract Entry
# 391      Contract Entry
# 392       Account Admin
# 393       Account Admin
# 394      Contract Entry
# 395      Contract Entry
# 396       Account Admin
# 397      Contract Entry
# 398       Account Admin
# 399      Contract Entry
# 400      Contract Entry
# 401      Contract Entry
# 402       Account Admin
# 403      Contract Entry
# 404       Account Admin
# 405      Contract Entry
# 406       Account Admin
# 407      Contract Entry
# 408      Contract Entry
# 409  Approval - Manager
# 410      Contract Entry
# 411      Contract Entry
# 412  Approval - Manager
# 413  Approval - Manager
# 414      Contract Entry
# 415      Contract Entry
# 416      Contract Entry
# 417       Account Admin
# 418      Contract Entry
# 419      Contract Entry
# 420      Contract Entry
# 421       Account Admin
# 422      Contract Entry
# 423  Approval - Manager
# 424       Account Admin
# 425       Account Admin
# 426      Contract Entry
# 427       Account Admin
# 428       Account Admin
# 429       Account Admin
# 430       Account Admin
# 431  Approval - Manager
# 432      Contract Entry
# 433      Contract Entry
# 434  Approval - Manager
# 435  Approval - Manager
# 436      Contract Entry
# 437       Account Admin
# 438      Contract Entry
# 439  Approval - Manager
# 440  Approval - Manager
# 441      Contract Entry
# 442  Approval - Manager
# 443      Contract Entry
# 444      Contract Entry
# 445       Account Admin
# 446       Account Admin
# 447       Account Admin
# 448  Approval - Manager
# 449      Contract Entry
# 450  Approval - Manager
# 451  Approval - Manager
# 452      Contract Entry
# 453      Contract Entry
# 454      Contract Entry
# 455      Contract Entry
# 456      Contract Entry
# 457       Account Admin
# 458  Approval - Manager
# 459       Account Admin
# 460       Account Admin
# 461      Contract Entry
# 462      Contract Entry
# 463      Contract Entry
# 464       Account Admin
# 465      Contract Entry
# 466       Account Admin
# 467      Contract Entry
# 468      Contract Entry
# 469  Approval - Manager
# 470      Contract Entry
# 471       Account Admin
# 472       Account Admin
# 473       Account Admin
# 474  Approval - Manager
# 475       Account Admin
# 476      Contract Entry
# 477       Account Admin
# 478      Contract Entry
# 479       Account Admin
# 480      Contract Entry
# 481       Account Admin
# 482       Account Admin
# 483       Account Admin
# 484  Approval - Manager
# 485      Contract Entry
# 486       Account Admin
# 487       Account Admin
# 488      Contract Entry
# 489      Contract Entry
# 490       Account Admin
# 491      Contract Entry
# 492       Account Admin
# 493       Account Admin
# 494       Account Admin
# 495      Contract Entry
# 496       Account Admin
# 497  Approval - Manager
# 498      Contract Entry
# 499       Account Admin
# 500       Account Admin
# 501       Account Admin
# 502       Account Admin
# 503      Contract Entry
# 504      Contract Entry
# 505       Account Admin
# 506      Contract Entry
# 507       Account Admin
# 508       Account Admin
# 509       Account Admin
# 510      Contract Entry
# 511      Contract Entry
# 512      Contract Entry
# 513       Account Admin
# 514      Contract Entry
# 515      Contract Entry
# 516      Contract Entry
# 517  Approval - Manager
# 518      Contract Entry
# 519      Contract Entry
# 520      Contract Entry
# 521      Contract Entry
# 522      Contract Entry
# 523  Approval - Manager
# 524      Contract Entry
# 525       Account Admin
# 526       Account Admin
# 527      Contract Entry
# 528      Contract Entry
# 529       Account Admin
# 530       Account Admin
# 531       Account Admin
# 532      Contract Entry
# 533      Contract Entry
# 534      Contract Entry
# 535       Account Admin
# 536      Contract Entry
# 537      Contract Entry
# 538       Account Admin
# 539  Approval - Manager
# 540       Account Admin
# 541       Account Admin
# 542      Contract Entry
# 543      Contract Entry
# 544       Account Admin
# 545      Contract Entry
# 546      Contract Entry
# 547       Account Admin
# 548      Contract Entry
# 549      Contract Entry
# 550      Contract Entry
# 551       Account Admin
# 552      Contract Entry
# 553  Approval - Manager
# 554       Account Admin
# 555      Contract Entry
# 556      Contract Entry
# 557       Account Admin
# 558       Account Admin
# 559      Contract Entry
# 560      Contract Entry
# 561      Contract Entry
# 562      Contract Entry
# 563       Account Admin
# 564      Contract Entry
# 565      Contract Entry
# 566  Approval - Manager
# 567      Contract Entry
# 568       Account Admin
# 569       Account Admin
# 570      Contract Entry
# 571       Account Admin
# 572       Account Admin
# 573  Approval - Manager
# 574      Contract Entry
# 575      Contract Entry
# 576      Contract Entry
# 577      Contract Entry
# 578       Account Admin
# 579  Approval - Manager
# 580       Account Admin
# 581      Contract Entry
# 582      Contract Entry
# 583      Contract Entry
# 584      Contract Entry
# 585      Contract Entry
# 586      Contract Entry
# 587       Account Admin
# 588      Contract Entry
# 589       Account Admin
# 590      Contract Entry
# 591      Contract Entry
# 592       Account Admin
# 593  Approval - Manager
# 594      Contract Entry
# 595      Contract Entry
# 596      Contract Entry
# 597       Account Admin
# 598       Account Admin
# 599      Contract Entry
# 600      Contract Entry
# 601       Account Admin
# 602       Account Admin
# 603       Account Admin
# 604      Contract Entry
# 605       Account Admin
# 606      Contract Entry
# 607      Contract Entry
# 608      Contract Entry
# 609      Contract Entry
# 610       Account Admin
# 611  Approval - Manager
# 612       Account Admin
# 613      Contract Entry
# 614      Contract Entry
# 615      Contract Entry
# 616       Account Admin
# 617       Account Admin
# 618       Account Admin
# 619       Account Admin
# 620       Account Admin
# 621      Contract Entry
# 622      Contract Entry
# 623      Contract Entry
# 624      Contract Entry
# 625      Contract Entry
# 626      Contract Entry
# 627       Account Admin
# 628       Account Admin
# 629       Account Admin
# 630  Approval - Manager
# 631      Contract Entry
# 632       Account Admin
# 633  Approval - Manager
# 634      Contract Entry
# 635  Approval - Manager
# 636      Contract Entry
# 637      Contract Entry
# 638      Contract Entry
# 639      Contract Entry
# 640       Account Admin
# 641  Approval - Manager
# 642      Contract Entry
# 643  Approval - Manager
# 644  Approval - Manager
# 645       Account Admin
# 646      Contract Entry
# 647      Contract Entry
# 648      Contract Entry
# 649  Approval - Manager
# 650       Account Admin
# 651      Contract Entry
# 652       Account Admin
# 653      Contract Entry
# 654      Contract Entry
# 655      Contract Entry
# 656       Account Admin
# 657       Account Admin
# 658       Account Admin
# 659       Account Admin
# 660      Contract Entry
# 661       Account Admin
# 662       Account Admin
# 663      Contract Entry
# 664  Approval - Manager
# 665      Contract Entry
# 666      Contract Entry
# 667      Contract Entry
# 668      Contract Entry
# 669      Contract Entry
# 670       Account Admin
# 671  Approval - Manager
# 672       Account Admin
# 673      Contract Entry
# 674       Account Admin
# 675       Account Admin
# 676       Account Admin
# 677       Account Admin
# 678      Contract Entry
# 679      Contract Entry
# 680      Contract Entry
# 681       Account Admin
# 682      Contract Entry
# 683      Contract Entry
# 684       Account Admin
# 685      Contract Entry
# 686  Approval - Manager
# 687       Account Admin
# 688      Contract Entry
# 689      Contract Entry
# 690  Approval - Manager
# 691      Contract Entry
# 692      Contract Entry
# 693      Contract Entry
# 694       Account Admin
# 695      Contract Entry
# 696      Contract Entry
# 697       Account Admin
# 698      Contract Entry
# 699       Account Admin
# 700      Contract Entry
# 701      Contract Entry
# 702      Contract Entry
# 703       Account Admin
# 704      Contract Entry
# 705       Account Admin
# 706       Account Admin
# 707      Contract Entry
# 708       Account Admin
# 709      Contract Entry
# 710      Contract Entry
# 711      Contract Entry
# 712      Contract Entry
# 713      Contract Entry
# 714      Contract Entry
# 715  Approval - Manager
# 716      Contract Entry
# 717      Contract Entry
# 718      Contract Entry
# 719      Contract Entry
# 720      Contract Entry
# 721  Approval - Manager
# 722       Account Admin
# 723  Approval - Manager
# 724       Account Admin
# 725  Approval - Manager
# 726      Contract Entry
# 727       Account Admin
# 728       Account Admin
# 729      Contract Entry
# 730      Contract Entry
# 731  Approval - Manager
# 732      Contract Entry
# 733       Account Admin
# 734      Contract Entry
# 735      Contract Entry
# 736      Contract Entry
# 737       Account Admin
# 738      Contract Entry
# 739      Contract Entry
# 740      Contract Entry
# 741       Account Admin
# 742      Contract Entry
# 743       Account Admin
# 744      Contract Entry
# 745       Account Admin
# 746      Contract Entry
# 747  Approval - Manager
# 748       Account Admin
# 749       Account Admin
# 750       Account Admin
# 751       Account Admin
# 752       Account Admin
# 753       Account Admin
# 754       Account Admin
# 755      Contract Entry
# 756      Contract Entry
# 757      Contract Entry
# 758       Account Admin
# 759       Account Admin
# 760      Contract Entry
# 761       Account Admin
# 762       Account Admin
# 763       Account Admin
# 764       Account Admin
# 765       Account Admin
# 766      Contract Entry
# 767      Contract Entry
# 768       Account Admin
# 769      Contract Entry
# 770       Account Admin
# 771  Approval - Manager
# 772       Account Admin
# 773       Account Admin
# 774      Contract Entry
# 775      Contract Entry
# 776      Contract Entry
# 777       Account Admin
# 778       Account Admin
# 779      Contract Entry
# 780  Approval - Manager
# 781       Account Admin
# 782       Account Admin
# 783       Account Admin
# 784       Account Admin
# 785      Contract Entry
# 786  Approval - Manager
# 787       Account Admin
# 788  Approval - Manager
# 789  Approval - Manager
# 790      Contract Entry
# 791       Account Admin
# 792  Approval - Manager
# 793      Contract Entry
# 794      Contract Entry
# 795       Account Admin
# 796      Contract Entry
# 797       Account Admin
# 798      Contract Entry
# 799       Account Admin
# 800      Contract Entry
# 801       Account Admin
# 802       Account Admin
# 803      Contract Entry
# 804       Account Admin
# 805       Account Admin
# 806      Contract Entry
# 807      Contract Entry
# 808      Contract Entry
# 809      Contract Entry
# 810       Account Admin
# 811      Contract Entry
# 812       Account Admin
# 813      Contract Entry
# 814       Account Admin
# 815       Account Admin
# 816       Account Admin
# 817      Contract Entry
# 818      Contract Entry
# 819      Contract Entry
# 820      Contract Entry
# 821       Account Admin
# 822       Account Admin
# 823       Account Admin
# 824       Account Admin
# 825      Contract Entry
# 826       Account Admin
# 827      Contract Entry
# 828       Account Admin
# 829  Approval - Manager
# 830      Contract Entry
# 831      Contract Entry
# 832       Account Admin
# 833      Contract Entry
# 834      Contract Entry
# 835       Account Admin
# 836      Contract Entry
# 837       Account Admin
# 838       Account Admin
# 839       Account Admin
# 840      Contract Entry
# 841       Account Admin
# 842       Account Admin
# 843      Contract Entry
# 844      Contract Entry
# 845       Account Admin
# 846       Account Admin
# 847      Contract Entry
# 848      Contract Entry
# 849      Contract Entry
# 850       Account Admin
# 851       Account Admin
# 852       Account Admin
# 853       Account Admin
# 854      Contract Entry
# 855      Contract Entry
# 856       Account Admin
# 857      Contract Entry
# 858      Contract Entry
# 859       Account Admin
# 860       Account Admin
# 861       Account Admin
# 862      Contract Entry
# 863      Contract Entry
# 864      Contract Entry
# 865       Account Admin
# 866       Account Admin
# 867       Account Admin
# 868      Contract Entry
# 869       Account Admin
# 870      Contract Entry
# 871      Contract Entry
# 872      Contract Entry
# 873       Account Admin
# 874      Contract Entry
# 875      Contract Entry
# 876       Account Admin
# 877      Contract Entry
# 878       Account Admin
# 879      Contract Entry
# 880      Contract Entry
# 881      Contract Entry
# 882       Account Admin
# 883       Account Admin
# 884       Account Admin
# 885      Contract Entry
# 886      Contract Entry
# 887      Contract Entry
# 888       Account Admin
# 889  Approval - Manager
# 890       Account Admin
# 891       Account Admin
# 892       Account Admin
# 893      Contract Entry
# 894      Contract Entry
# 895      Contract Entry
# 896       Account Admin
# 897       Account Admin
# 898       Account Admin
# 899  Approval - Manager
# 900      Contract Entry
# 901  Approval - Manager
# 902       Account Admin
# 903      Contract Entry
# 904      Contract Entry
# 905       Account Admin
# 906      Contract Entry
# 907  Approval - Manager
# 908      Contract Entry
# 909       Account Admin
# 910       Account Admin
# 911       Account Admin
# 912       Account Admin
# 913      Contract Entry
# 914       Account Admin
# 915      Contract Entry
# 916  Approval - Manager
# 917      Contract Entry
# 918       Account Admin
# 919       Account Admin
# 920      Contract Entry
# 921      Contract Entry
# 922      Contract Entry
# 923      Contract Entry
# 924       Account Admin
# 925      Contract Entry
# 926  Approval - Manager
# 927      Contract Entry
# 928       Account Admin
# 929       Account Admin
# 930       Account Admin
# 931  Approval - Manager
# 932       Account Admin
# 933       Account Admin
# 934      Contract Entry
# 935      Contract Entry
# 936  Approval - Manager
# 937       Account Admin
# 938       Account Admin
# 939      Contract Entry
# 940      Contract Entry
# 941       Account Admin
# 942       Account Admin
# 943       Account Admin
# 944      Contract Entry
# 945      Contract Entry
# 946      Contract Entry
# 947      Contract Entry
# 948       Account Admin
# 949      Contract Entry
# 950      Contract Entry
# 951      Contract Entry
# 952      Contract Entry
# 953       Account Admin
# 954       Account Admin
# 955       Account Admin
# 956  Approval - Manager
# 957       Account Admin
# 958      Contract Entry
# 959       Account Admin
# 960       Account Admin
# 961       Account Admin
# 962       Account Admin
# 963       Account Admin
# 964       Account Admin
# 965      Contract Entry
# 966      Contract Entry
# 967  Approval - Manager
# 968      Contract Entry
# 969      Contract Entry
# 970      Contract Entry
# 971       Account Admin
# 972      Contract Entry
# 973       Account Admin
# 974       Account Admin

# %%
# NOTAS & Uncleaned Work


import pandas as pd
import numpy as np

# Change later so others can get it on their computer (debaaaaaaaaaaaaajo)

employees = pd.read_csv("C:/Users/Michael Botelho/bip-python-unh/user_audit/data/employees.csv")
system_access = pd.read_csv("C:/Users/Michael Botelho/bip-python-unh/user_audit/data/system_access.csv")



#########################################################################################################################
##### Trying to clean the ID's in System Access

#system_access['id'] = ['EMP'.zfill(6)]
#system_access['id'] = system_access['id'].apply('EMP'.zfill(6))
#system_access['id'] = system_access['id'].apply('EMP'.zfill(6))
#print(system_access)
#print(employees)

##### Cleaning ID's that works
system_access = system_access.astype(str)
str(system_access['id'])
system_access['id'] = system_access['id'].apply('EMP''{:0>6}'.format)
str(employees['employee_number'])

##### Merge Datasets
#df = pd.merge(employees, system_access, left_on='employee_number', right_on='id', inplace=True)
df = pd.merge(employees, system_access, left_on='employee_number', right_on='id',  how='outer')
df

##### Filter for missing values

df.isnull().any()

df

##### Subset of records that are missing
 
nd = df[df.isnull().any(axis=1)]


##### if title = x then access level = z : .iloc .loc ?????

#null_data.loc[null_data.title == 'Sales Assistant', null_data.access_level] = 'Contract Entry'
#df.loc[['viper', 'sidewinder'], ['shield']] = 50
#null_data.loc[null_data.title == 'Sales Assistant', null_data.access_level] = 'Contract Entry'
#df.loc[df['set_of_numbers'] <= 4, 'equal_or_lower_than_4?'] = 'True' 
#null_data.loc[null_data['title'] == 'Sales Assistant', null_data['access_level']] = 'Contract Entry'
#nd.loc[nd['title'].isnull(),'Sales Assistant'] = nd['access_level']
#nd.loc['Sales Assistant'], nd['access_level'] = 'Contract Entry'
#nd['access_level1'] = np.where(nd.title== 'Sales Assistant', 'Contract Entry')
#nd.loc[nd['title'] == 'Sales Assistant'] = 'Contract Entry'
#conditions = [
#    (nd['title'] == 'Sales Assistant'),
 #   (nd['title'] == 'Account Manager'),
#(nd['title'] == 'Director of Sales')]
#values = ['Contract Entry', 'Account Admin', 'Approval - Manager']
#pd.options.mode.chained_assignment = None  # default='warn'
#del nd['access_level']
#nd['access_level'] = np.select(conditions, values)
#nd

##### This works


conditions = [
    (df['title'] == 'Sales Assistant'),
    (df['title'] == 'Account Manager'),
(df['title'] == 'Director of Sales')]

values = ['Contract Entry', 'Account Admin', 'Approval - Manager']
df['access_level'] = np.select(conditions, values)
del df['id']
#pd.set_option('display.max_rows', None)

# %%
# Do this stuff later (for the importing)

import pandas as pd

def load_data():
    df_contracts = pd.read_csv('../data/contracts.csv')
    df_customers = pd.read_csv('../data/customers.csv')
    return df_contracts, df_customers

def combine_data(df_contracts, df_customers):
    df_customers.rename(columns={'id':'customer_id'}, inplace=True)
    df_customers.set_index('customer_id', inplace=True)
    df_contracts.set_index('customer_id', inplace=True)
    df = df_contracts.join(df_customers, how='left')
    return df

# %%
import sys
sys.path.insert(1, '../src')
import ians_work
