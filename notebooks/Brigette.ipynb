# %%
import pandas as pd
pd.__version__
# Out:
# '1.1.3'

# %%
import pandas as pd

employees = pd.read_csv (r'/Users/brigettethompson/bip-python-unh/user_audit/data/employees.csv')
print (employees)
# Out:
#     employee_number  first_name   last_name  \
# 0         EMP003037     Juliana    Burbudge
# 1         EMP003045      Lizzie        Blue
# 2         EMP003051     Marjory    Selcraig
# 3         EMP003068      Aguste    O'Connor
# 4         EMP003097     Clemens      Kopman
# ..              ...         ...         ...
# 970       EMP024864    Kristina       Yakov
# 971       EMP024885   Margarita  Habbergham
# 972       EMP024890    Prescott   Southward
# 973       EMP024896       Raine     Learned
# 974       EMP024931  Frederique        Fant
#
#                                     email              title
# 0        juliana.burbudge@consultants.com  Director of Sales
# 1             lizzie.blue@consultants.com    Sales Assistant
# 2        marjory.selcraig@consultants.com    Sales Assistant
# 3         aguste.o'connor@consultants.com    Sales Assistant
# 4          clemens.kopman@consultants.com    Account Manager
# ..                                    ...                ...
# 970        kristina.yakov@consultants.com    Sales Assistant
# 971  margarita.habbergham@consultants.com    Account Manager
# 972    prescott.southward@consultants.com    Sales Assistant
# 973         raine.learned@consultants.com    Account Manager
# 974       frederique.fant@consultants.com    Account Manager
#
# [975 rows x 5 columns]

# %%
import pandas as pd

system_access = pd.read_csv (r'/Users/brigettethompson/bip-python-unh/user_audit/data/system_access.csv')
print (system_access)
# Out:
#         id    access_level
# 0     3045  Contract Entry
# 1     3051  Contract Entry
# 2     3068  Contract Entry
# 3     3097   Account Admin
# 4     3133  Contract Entry
# ..     ...             ...
# 833  24862  Contract Entry
# 834  24864  Contract Entry
# 835  24885   Account Admin
# 836  24890  Contract Entry
# 837  24896   Account Admin
#
# [838 rows x 2 columns]

# %%
system_access.rename(columns={'id':'employee_number'}, inplace=True)
system_access['employee_number'] = system_access['employee_number'].apply(lambda x: '{0:0>06}'.format(x))
system_access['employee_number'] = 'EMP' + system_access['employee_number'].astype(str)

system_access
# Out:
#     employee_number    access_level
# 0         EMP003045  Contract Entry
# 1         EMP003051  Contract Entry
# 2         EMP003068  Contract Entry
# 3         EMP003097   Account Admin
# 4         EMP003133  Contract Entry
# ..              ...             ...
# 833       EMP024862  Contract Entry
# 834       EMP024864  Contract Entry
# 835       EMP024885   Account Admin
# 836       EMP024890  Contract Entry
# 837       EMP024896   Account Admin
#
# [838 rows x 2 columns]

# %%
system_access.set_index('employee_number', inplace=True)
employees.set_index('employee_number', inplace=True)
employees
# Out:
#                  first_name   last_name                                 email  \
# employee_number
# EMP003037           Juliana    Burbudge      juliana.burbudge@consultants.com
# EMP003045            Lizzie        Blue           lizzie.blue@consultants.com
# EMP003051           Marjory    Selcraig      marjory.selcraig@consultants.com
# EMP003068            Aguste    O'Connor       aguste.o'connor@consultants.com
# EMP003097           Clemens      Kopman        clemens.kopman@consultants.com
# ...                     ...         ...                                   ...
# EMP024864          Kristina       Yakov        kristina.yakov@consultants.com
# EMP024885         Margarita  Habbergham  margarita.habbergham@consultants.com
# EMP024890          Prescott   Southward    prescott.southward@consultants.com
# EMP024896             Raine     Learned         raine.learned@consultants.com
# EMP024931        Frederique        Fant       frederique.fant@consultants.com
#
#                              title
# employee_number
# EMP003037        Director of Sales
# EMP003045          Sales Assistant
# EMP003051          Sales Assistant
# EMP003068          Sales Assistant
# EMP003097          Account Manager
# ...                            ...
# EMP024864          Sales Assistant
# EMP024885          Account Manager
# EMP024890          Sales Assistant
# EMP024896          Account Manager
# EMP024931          Account Manager
#
# [975 rows x 4 columns]

# %%
system_access
# Out:
#                    access_level
# employee_number
# EMP003045        Contract Entry
# EMP003051        Contract Entry
# EMP003068        Contract Entry
# EMP003097         Account Admin
# EMP003133        Contract Entry
# ...                         ...
# EMP024862        Contract Entry
# EMP024864        Contract Entry
# EMP024885         Account Admin
# EMP024890        Contract Entry
# EMP024896         Account Admin
#
# [838 rows x 1 columns]

# %%
df = employees.join(system_access, how='left')

df
# Out:
#                  first_name   last_name                                 email  \
# employee_number
# EMP003037           Juliana    Burbudge      juliana.burbudge@consultants.com
# EMP003045            Lizzie        Blue           lizzie.blue@consultants.com
# EMP003051           Marjory    Selcraig      marjory.selcraig@consultants.com
# EMP003068            Aguste    O'Connor       aguste.o'connor@consultants.com
# EMP003097           Clemens      Kopman        clemens.kopman@consultants.com
# ...                     ...         ...                                   ...
# EMP024864          Kristina       Yakov        kristina.yakov@consultants.com
# EMP024885         Margarita  Habbergham  margarita.habbergham@consultants.com
# EMP024890          Prescott   Southward    prescott.southward@consultants.com
# EMP024896             Raine     Learned         raine.learned@consultants.com
# EMP024931        Frederique        Fant       frederique.fant@consultants.com
#
#                              title    access_level
# employee_number
# EMP003037        Director of Sales             NaN
# EMP003045          Sales Assistant  Contract Entry
# EMP003051          Sales Assistant  Contract Entry
# EMP003068          Sales Assistant  Contract Entry
# EMP003097          Account Manager   Account Admin
# ...                            ...             ...
# EMP024864          Sales Assistant  Contract Entry
# EMP024885          Account Manager   Account Admin
# EMP024890          Sales Assistant  Contract Entry
# EMP024896          Account Manager   Account Admin
# EMP024931          Account Manager             NaN
#
# [975 rows x 5 columns]

# %%
null_data = df[df.isnull().any(axis=1)]
null_data
# Out:
#                  first_name last_name                             email  \
# employee_number
# EMP003037           Juliana  Burbudge  juliana.burbudge@consultants.com
# EMP003265            Natala      Judd       natala.judd@consultants.com
# EMP003291           Gweneth    Abbate    gweneth.abbate@consultants.com
# EMP003684          Annmarie   Scrange  annmarie.scrange@consultants.com
# EMP003713          Marybeth   Driussi  marybeth.driussi@consultants.com
# ...                     ...       ...                               ...
# EMP024068           Celinka   Vasilic   celinka.vasilic@consultants.com
# EMP024191             Danny    Vinten      danny.vinten@consultants.com
# EMP024501            Fedora     Belle      fedora.belle@consultants.com
# EMP024551              Ravi   Dighton      ravi.dighton@consultants.com
# EMP024931        Frederique      Fant   frederique.fant@consultants.com
#
#                              title access_level
# employee_number
# EMP003037        Director of Sales          NaN
# EMP003265        Director of Sales          NaN
# EMP003291          Account Manager          NaN
# EMP003684        Director of Sales          NaN
# EMP003713          Account Manager          NaN
# ...                            ...          ...
# EMP024068        Director of Sales          NaN
# EMP024191        Director of Sales          NaN
# EMP024501          Sales Assistant          NaN
# EMP024551          Account Manager          NaN
# EMP024931          Account Manager          NaN
#
# [137 rows x 5 columns]

# %%
df.loc[df['title'] <= "Account Manager", 'access_level'] = 'Account Admin'

df
# Out:
#                  first_name   last_name                                 email  \
# employee_number
# EMP003037           Juliana    Burbudge      juliana.burbudge@consultants.com
# EMP003045            Lizzie        Blue           lizzie.blue@consultants.com
# EMP003051           Marjory    Selcraig      marjory.selcraig@consultants.com
# EMP003068            Aguste    O'Connor       aguste.o'connor@consultants.com
# EMP003097           Clemens      Kopman        clemens.kopman@consultants.com
# ...                     ...         ...                                   ...
# EMP024864          Kristina       Yakov        kristina.yakov@consultants.com
# EMP024885         Margarita  Habbergham  margarita.habbergham@consultants.com
# EMP024890          Prescott   Southward    prescott.southward@consultants.com
# EMP024896             Raine     Learned         raine.learned@consultants.com
# EMP024931        Frederique        Fant       frederique.fant@consultants.com
#
#                              title    access_level
# employee_number
# EMP003037        Director of Sales             NaN
# EMP003045          Sales Assistant  Contract Entry
# EMP003051          Sales Assistant  Contract Entry
# EMP003068          Sales Assistant  Contract Entry
# EMP003097          Account Manager   Account Admin
# ...                            ...             ...
# EMP024864          Sales Assistant  Contract Entry
# EMP024885          Account Manager   Account Admin
# EMP024890          Sales Assistant  Contract Entry
# EMP024896          Account Manager   Account Admin
# EMP024931          Account Manager   Account Admin
#
# [975 rows x 5 columns]

# %%
null_data = df[df.isnull().any(axis=1)]
null_data
# Out:
#                   first_name   last_name  \
# employee_number
# EMP003037            Juliana    Burbudge
# EMP003265             Natala        Judd
# EMP003684           Annmarie     Scrange
# EMP003921           Sigfried      McTear
# EMP004461           Josselyn    Ivanchov
# ...                      ...         ...
# EMP023866            Jeramey      Dondon
# EMP023935        Ulrikaumeko  Plumridege
# EMP024068            Celinka     Vasilic
# EMP024191              Danny      Vinten
# EMP024501             Fedora       Belle
#
#                                                   email              title  \
# employee_number
# EMP003037              juliana.burbudge@consultants.com  Director of Sales
# EMP003265                   natala.judd@consultants.com  Director of Sales
# EMP003684              annmarie.scrange@consultants.com  Director of Sales
# EMP003921               sigfried.mctear@consultants.com  Director of Sales
# EMP004461             josselyn.ivanchov@consultants.com    Sales Assistant
# ...                                                 ...                ...
# EMP023866                jeramey.dondon@consultants.com  Director of Sales
# EMP023935        ulrikaumeko.plumridege@consultants.com  Director of Sales
# EMP024068               celinka.vasilic@consultants.com  Director of Sales
# EMP024191                  danny.vinten@consultants.com  Director of Sales
# EMP024501                  fedora.belle@consultants.com    Sales Assistant
#
#                 access_level
# employee_number
# EMP003037                NaN
# EMP003265                NaN
# EMP003684                NaN
# EMP003921                NaN
# EMP004461                NaN
# ...                      ...
# EMP023866                NaN
# EMP023935                NaN
# EMP024068                NaN
# EMP024191                NaN
# EMP024501                NaN
#
# [89 rows x 5 columns]

# %%
df
# Out:
#                  first_name   last_name                                 email  \
# employee_number
# EMP003037           Juliana    Burbudge      juliana.burbudge@consultants.com
# EMP003045            Lizzie        Blue           lizzie.blue@consultants.com
# EMP003051           Marjory    Selcraig      marjory.selcraig@consultants.com
# EMP003068            Aguste    O'Connor       aguste.o'connor@consultants.com
# EMP003097           Clemens      Kopman        clemens.kopman@consultants.com
# ...                     ...         ...                                   ...
# EMP024864          Kristina       Yakov        kristina.yakov@consultants.com
# EMP024885         Margarita  Habbergham  margarita.habbergham@consultants.com
# EMP024890          Prescott   Southward    prescott.southward@consultants.com
# EMP024896             Raine     Learned         raine.learned@consultants.com
# EMP024931        Frederique        Fant       frederique.fant@consultants.com
#
#                              title    access_level
# employee_number
# EMP003037        Director of Sales             NaN
# EMP003045          Sales Assistant  Contract Entry
# EMP003051          Sales Assistant  Contract Entry
# EMP003068          Sales Assistant  Contract Entry
# EMP003097          Account Manager   Account Admin
# ...                            ...             ...
# EMP024864          Sales Assistant  Contract Entry
# EMP024885          Account Manager   Account Admin
# EMP024890          Sales Assistant  Contract Entry
# EMP024896          Account Manager   Account Admin
# EMP024931          Account Manager   Account Admin
#
# [975 rows x 5 columns]

# %%
df.loc[df['title'] >= "Sales Assistant", 'access_level'] = 'Contract Entry'
df
# Out:
#                  first_name   last_name                                 email  \
# employee_number
# EMP003037           Juliana    Burbudge      juliana.burbudge@consultants.com
# EMP003045            Lizzie        Blue           lizzie.blue@consultants.com
# EMP003051           Marjory    Selcraig      marjory.selcraig@consultants.com
# EMP003068            Aguste    O'Connor       aguste.o'connor@consultants.com
# EMP003097           Clemens      Kopman        clemens.kopman@consultants.com
# ...                     ...         ...                                   ...
# EMP024864          Kristina       Yakov        kristina.yakov@consultants.com
# EMP024885         Margarita  Habbergham  margarita.habbergham@consultants.com
# EMP024890          Prescott   Southward    prescott.southward@consultants.com
# EMP024896             Raine     Learned         raine.learned@consultants.com
# EMP024931        Frederique        Fant       frederique.fant@consultants.com
#
#                              title    access_level
# employee_number
# EMP003037        Director of Sales             NaN
# EMP003045          Sales Assistant  Contract Entry
# EMP003051          Sales Assistant  Contract Entry
# EMP003068          Sales Assistant  Contract Entry
# EMP003097          Account Manager   Account Admin
# ...                            ...             ...
# EMP024864          Sales Assistant  Contract Entry
# EMP024885          Account Manager   Account Admin
# EMP024890          Sales Assistant  Contract Entry
# EMP024896          Account Manager   Account Admin
# EMP024931          Account Manager   Account Admin
#
# [975 rows x 5 columns]

# %%
null_data = df[df.isnull().any(axis=1)]
null_data
# Out:
#                   first_name     last_name  \
# employee_number
# EMP003037            Juliana      Burbudge
# EMP003265             Natala          Judd
# EMP003684           Annmarie       Scrange
# EMP003921           Sigfried        McTear
# EMP004708            Carling       Janecek
# EMP005134               Jami       Cornall
# EMP005242            Sheilah      Castagne
# EMP005289          Cassandra      Ritmeier
# EMP005889              Fanni          Aird
# EMP006091              Caryn      Spackman
# EMP006453          Josephina         Easby
# EMP006956              Anson       Yakubov
# EMP007342              Aldon        Patron
# EMP008420            Madison       Yurygyn
# EMP008421             Lorene        Dutson
# EMP008451            Roxanna        Dungay
# EMP009354              Selig       Whittek
# EMP009879          Valentino     Mattiacci
# EMP010215             Carver       Grennan
# EMP010312             Warden        Starie
# EMP010369              Meggy        Hayhow
# EMP011112              Phebe       Bulleyn
# EMP011305          Hyacintha       Adamiec
# EMP011372          Claiborne         Rowet
# EMP012211            Vitoria          Dews
# EMP012626             Edmund       Kernley
# EMP012771             Jobyna        Pixton
# EMP012926           Mitchael       Lalevee
# EMP012961              Alika        Croser
# EMP013022         Christiana        Axelby
# EMP013210              Daisy       Quernel
# EMP013241           Atalanta        Edward
# EMP013578            Sephira    Throughton
# EMP014234              Byran      Stearley
# EMP015131               Glen      Blaskett
# EMP016079                Ruy      Burhouse
# EMP016364               Shaw      Sneesbie
# EMP017568              Ester         Akitt
# EMP017655           Rebbecca       Pluvier
# EMP017792             Wallis       Huddart
# EMP018294             Rhodie   Barraclough
# EMP018433                Rey         Turle
# EMP019164           Salomone       Benzing
# EMP019702            Annissa        Moorey
# EMP019760              Sibyl        Gerard
# EMP019814           Nikolaus       Getsham
# EMP019830           Clarisse        Ortell
# EMP020737               Gale       Vannini
# EMP020931             Kassia     Apfelmann
# EMP021091             Gillie        Rother
# EMP021215              Lilas         Alban
# EMP021261               Garv     Inchboard
# EMP023178                Dur          Nand
# EMP023428             Gibbie  Blackborough
# EMP023866            Jeramey        Dondon
# EMP023935        Ulrikaumeko    Plumridege
# EMP024068            Celinka       Vasilic
# EMP024191              Danny        Vinten
#
#                                                   email              title  \
# employee_number
# EMP003037              juliana.burbudge@consultants.com  Director of Sales
# EMP003265                   natala.judd@consultants.com  Director of Sales
# EMP003684              annmarie.scrange@consultants.com  Director of Sales
# EMP003921               sigfried.mctear@consultants.com  Director of Sales
# EMP004708               carling.janecek@consultants.com  Director of Sales
# EMP005134                  jami.cornall@consultants.com  Director of Sales
# EMP005242              sheilah.castagne@consultants.com  Director of Sales
# EMP005289            cassandra.ritmeier@consultants.com  Director of Sales
# EMP005889                    fanni.aird@consultants.com  Director of Sales
# EMP006091                caryn.spackman@consultants.com  Director of Sales
# EMP006453               josephina.easby@consultants.com  Director of Sales
# EMP006956                 anson.yakubov@consultants.com  Director of Sales
# EMP007342                  aldon.patron@consultants.com  Director of Sales
# EMP008420               madison.yurygyn@consultants.com  Director of Sales
# EMP008421                 lorene.dutson@consultants.com  Director of Sales
# EMP008451                roxanna.dungay@consultants.com  Director of Sales
# EMP009354                 selig.whittek@consultants.com  Director of Sales
# EMP009879           valentino.mattiacci@consultants.com  Director of Sales
# EMP010215                carver.grennan@consultants.com  Director of Sales
# EMP010312                 warden.starie@consultants.com  Director of Sales
# EMP010369                  meggy.hayhow@consultants.com  Director of Sales
# EMP011112                 phebe.bulleyn@consultants.com  Director of Sales
# EMP011305             hyacintha.adamiec@consultants.com  Director of Sales
# EMP011372               claiborne.rowet@consultants.com  Director of Sales
# EMP012211                  vitoria.dews@consultants.com  Director of Sales
# EMP012626                edmund.kernley@consultants.com  Director of Sales
# EMP012771                 jobyna.pixton@consultants.com  Director of Sales
# EMP012926              mitchael.lalevee@consultants.com  Director of Sales
# EMP012961                  alika.croser@consultants.com  Director of Sales
# EMP013022             christiana.axelby@consultants.com  Director of Sales
# EMP013210                 daisy.quernel@consultants.com  Director of Sales
# EMP013241               atalanta.edward@consultants.com  Director of Sales
# EMP013578            sephira.throughton@consultants.com  Director of Sales
# EMP014234                byran.stearley@consultants.com  Director of Sales
# EMP015131                 glen.blaskett@consultants.com  Director of Sales
# EMP016079                  ruy.burhouse@consultants.com  Director of Sales
# EMP016364                 shaw.sneesbie@consultants.com  Director of Sales
# EMP017568                   ester.akitt@consultants.com  Director of Sales
# EMP017655              rebbecca.pluvier@consultants.com  Director of Sales
# EMP017792                wallis.huddart@consultants.com  Director of Sales
# EMP018294            rhodie.barraclough@consultants.com  Director of Sales
# EMP018433                     rey.turle@consultants.com  Director of Sales
# EMP019164              salomone.benzing@consultants.com  Director of Sales
# EMP019702                annissa.moorey@consultants.com  Director of Sales
# EMP019760                  sibyl.gerard@consultants.com  Director of Sales
# EMP019814              nikolaus.getsham@consultants.com  Director of Sales
# EMP019830               clarisse.ortell@consultants.com  Director of Sales
# EMP020737                  gale.vannini@consultants.com  Director of Sales
# EMP020931              kassia.apfelmann@consultants.com  Director of Sales
# EMP021091                 gillie.rother@consultants.com  Director of Sales
# EMP021215                   lilas.alban@consultants.com  Director of Sales
# EMP021261                garv.inchboard@consultants.com  Director of Sales
# EMP023178                      dur.nand@consultants.com  Director of Sales
# EMP023428           gibbie.blackborough@consultants.com  Director of Sales
# EMP023866                jeramey.dondon@consultants.com  Director of Sales
# EMP023935        ulrikaumeko.plumridege@consultants.com  Director of Sales
# EMP024068               celinka.vasilic@consultants.com  Director of Sales
# EMP024191                  danny.vinten@consultants.com  Director of Sales
#
#                 access_level
# employee_number
# EMP003037                NaN
# EMP003265                NaN
# EMP003684                NaN
# EMP003921                NaN
# EMP004708                NaN
# EMP005134                NaN
# EMP005242                NaN
# EMP005289                NaN
# EMP005889                NaN
# EMP006091                NaN
# EMP006453                NaN
# EMP006956                NaN
# EMP007342                NaN
# EMP008420                NaN
# EMP008421                NaN
# EMP008451                NaN
# EMP009354                NaN
# EMP009879                NaN
# EMP010215                NaN
# EMP010312                NaN
# EMP010369                NaN
# EMP011112                NaN
# EMP011305                NaN
# EMP011372                NaN
# EMP012211                NaN
# EMP012626                NaN
# EMP012771                NaN
# EMP012926                NaN
# EMP012961                NaN
# EMP013022                NaN
# EMP013210                NaN
# EMP013241                NaN
# EMP013578                NaN
# EMP014234                NaN
# EMP015131                NaN
# EMP016079                NaN
# EMP016364                NaN
# EMP017568                NaN
# EMP017655                NaN
# EMP017792                NaN
# EMP018294                NaN
# EMP018433                NaN
# EMP019164                NaN
# EMP019702                NaN
# EMP019760                NaN
# EMP019814                NaN
# EMP019830                NaN
# EMP020737                NaN
# EMP020931                NaN
# EMP021091                NaN
# EMP021215                NaN
# EMP021261                NaN
# EMP023178                NaN
# EMP023428                NaN
# EMP023866                NaN
# EMP023935                NaN
# EMP024068                NaN
# EMP024191                NaN

# %%
df
# Out:
#                  first_name   last_name                                 email  \
# employee_number
# EMP003037           Juliana    Burbudge      juliana.burbudge@consultants.com
# EMP003045            Lizzie        Blue           lizzie.blue@consultants.com
# EMP003051           Marjory    Selcraig      marjory.selcraig@consultants.com
# EMP003068            Aguste    O'Connor       aguste.o'connor@consultants.com
# EMP003097           Clemens      Kopman        clemens.kopman@consultants.com
# ...                     ...         ...                                   ...
# EMP024864          Kristina       Yakov        kristina.yakov@consultants.com
# EMP024885         Margarita  Habbergham  margarita.habbergham@consultants.com
# EMP024890          Prescott   Southward    prescott.southward@consultants.com
# EMP024896             Raine     Learned         raine.learned@consultants.com
# EMP024931        Frederique        Fant       frederique.fant@consultants.com
#
#                              title    access_level
# employee_number
# EMP003037        Director of Sales             NaN
# EMP003045          Sales Assistant  Contract Entry
# EMP003051          Sales Assistant  Contract Entry
# EMP003068          Sales Assistant  Contract Entry
# EMP003097          Account Manager   Account Admin
# ...                            ...             ...
# EMP024864          Sales Assistant  Contract Entry
# EMP024885          Account Manager   Account Admin
# EMP024890          Sales Assistant  Contract Entry
# EMP024896          Account Manager   Account Admin
# EMP024931          Account Manager   Account Admin
#
# [975 rows x 5 columns]

# %%
df["access_level"].fillna("Approval - Manager", inplace = True)  
df
# Out:
#                  first_name   last_name                                 email  \
# employee_number
# EMP003037           Juliana    Burbudge      juliana.burbudge@consultants.com
# EMP003045            Lizzie        Blue           lizzie.blue@consultants.com
# EMP003051           Marjory    Selcraig      marjory.selcraig@consultants.com
# EMP003068            Aguste    O'Connor       aguste.o'connor@consultants.com
# EMP003097           Clemens      Kopman        clemens.kopman@consultants.com
# ...                     ...         ...                                   ...
# EMP024864          Kristina       Yakov        kristina.yakov@consultants.com
# EMP024885         Margarita  Habbergham  margarita.habbergham@consultants.com
# EMP024890          Prescott   Southward    prescott.southward@consultants.com
# EMP024896             Raine     Learned         raine.learned@consultants.com
# EMP024931        Frederique        Fant       frederique.fant@consultants.com
#
#                              title        access_level
# employee_number
# EMP003037        Director of Sales  Approval - Manager
# EMP003045          Sales Assistant      Contract Entry
# EMP003051          Sales Assistant      Contract Entry
# EMP003068          Sales Assistant      Contract Entry
# EMP003097          Account Manager       Account Admin
# ...                            ...                 ...
# EMP024864          Sales Assistant      Contract Entry
# EMP024885          Account Manager       Account Admin
# EMP024890          Sales Assistant      Contract Entry
# EMP024896          Account Manager       Account Admin
# EMP024931          Account Manager       Account Admin
#
# [975 rows x 5 columns]

# %%
df
# Out:
#                  first_name   last_name                                 email  \
# employee_number
# EMP003037           Juliana    Burbudge      juliana.burbudge@consultants.com
# EMP003045            Lizzie        Blue           lizzie.blue@consultants.com
# EMP003051           Marjory    Selcraig      marjory.selcraig@consultants.com
# EMP003068            Aguste    O'Connor       aguste.o'connor@consultants.com
# EMP003097           Clemens      Kopman        clemens.kopman@consultants.com
# ...                     ...         ...                                   ...
# EMP024864          Kristina       Yakov        kristina.yakov@consultants.com
# EMP024885         Margarita  Habbergham  margarita.habbergham@consultants.com
# EMP024890          Prescott   Southward    prescott.southward@consultants.com
# EMP024896             Raine     Learned         raine.learned@consultants.com
# EMP024931        Frederique        Fant       frederique.fant@consultants.com
#
#                              title        access_level
# employee_number
# EMP003037        Director of Sales  Approval - Manager
# EMP003045          Sales Assistant      Contract Entry
# EMP003051          Sales Assistant      Contract Entry
# EMP003068          Sales Assistant      Contract Entry
# EMP003097          Account Manager       Account Admin
# ...                            ...                 ...
# EMP024864          Sales Assistant      Contract Entry
# EMP024885          Account Manager       Account Admin
# EMP024890          Sales Assistant      Contract Entry
# EMP024896          Account Manager       Account Admin
# EMP024931          Account Manager       Account Admin
#
# [975 rows x 5 columns]

# %%
#use for reference https://github.com/ianstone-edu/sales_analysis

# %%
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html
